# %%
import pandas as pd 
filepath = "./data/masked_sentences_bert.txt"
filepath = "/mnt/a/nxml/data/all_bert.txt"
df = pd.read_table(filepath, header = None)
df.columns = ["Score","Year","PMCID","Gene","Experiment","Sentence","Masked"]
df
# Out:
#              Score  Year       PMCID    Gene        Experiment  \
# 0         0.586666  2003   PMC194750    cage           imaging
# 1         0.686265  2004   PMC468627  s100a7           in situ
# 2         0.955578  2004   PMC468627  s100a7               ihc
# 3         0.929193  2004   PMC468627  s100a7          staining
# 4         0.941197  2004   PMC468627  s100a7               ihc
# ...            ...   ...         ...     ...               ...
# 10939423  0.530666  2022  PMC9245671    hes4           rna-seq
# 10939424  0.913970  2022  PMC9344698    egfr     overexpressed
# 10939425  0.529534  2022  PMC9344698    egfr  western blotting
# 10939426  0.920681  2022  PMC9351700    cd45    flow cytometry
# 10939427  0.943375  2022  PMC9360556    mlkl            probed
#
#                                                    Sentence  \
# 0         Open boxes: when mouse was out of cage for ima...
# 1         In cases of DCIS associated with invasive carc...
# 2         The S100A7 IHC scores ranged from 0 to 270 (me...
# 3         Representative examples of S100A7 staining are...
# 4         Furthermore, the overall S100A7 IHC scores wer...
# ...                                                     ...
# 10939423  ( A ) Receiver operating characteristic curve ...
# 10939424  To demonstrate that the CPT11-loaded liposome ...
# 10939425  To demonstrate that the CPT11-loaded liposome ...
# 10939426  Remarkably, flow cytometry analysis revealed t...
# 10939427  To assess whether treatment with emricasan res...
#
#                                                      Masked
# 0          Open boxes: when mouse was out of [GENE] for ...
# 1          In cases of DCIS associated with invasive car...
# 2          The [GENE] [EXPE] scores ranged from 0 to 270...
# 3          Representative examples of [GENE] [EXPE] are ...
# 4          Furthermore the overall [GENE] [EXPE] scores ...
# ...                                                     ...
# 10939423     A   Receiver operating characteristic curve...
# 10939424   To demonstrate that the CPT11-loaded liposome...
# 10939425   To demonstrate that the CPT11-loaded liposome...
# 10939426   Remarkably [EXPE] analysis revealed that the ...
# 10939427   To assess whether treatment with emricasan re...
#
# [10939428 rows x 7 columns]

# %%
grouped = df.groupby('PMCID')
sent_ids = []

# Loop through each PMCID group
for _, group in grouped:
    sentences = group["Sentence"].tolist()
    sent_id = 1
    sent_ids.append(sent_id)
    
    # Check for consecutive sentences
    for i in range(1, len(sentences)):
        if sentences[i] != sentences[i-1]:
            sent_id += 1
        sent_ids.append(sent_id)

# Add as a new column
df["SentID"] = sent_ids

# %%
# !ls ../
# Out:
#  Main-latest2023-Copy2-Masking.ipynb   Repository.tar.gz        lexas	    tmp
# 'Old Firefox Data'		       biobert		        lexas-old
#  README.md			       codwe		        lexas-tmp
#  Repository			       ijo_50_3_920_PDF-1.pdf   old

# %%
import random
import pandas as pd
random.seed(100)

pairs = []
while len(pairs) < 1000:
    idx = random.randint(0, len(df) - 2)
    row1, row2 = df.iloc[idx], df.iloc[idx+1]
    
    # Check if rows have the same PMCID and different sentences
    if row1["PMCID"] == row2["PMCID"] and row1["Sentence"] != row2["Sentence"]:
        pp = row1["PMCID"]
        pairs.append((f"https://www.ncbi.nlm.nih.gov/pmc/articles/{pp}", row1["Sentence"], row2["Sentence"], row1["Gene"], row2["Gene"]))

pairs_df = pd.DataFrame(pairs, columns=["PMCID", "Sentence1", "Sentence2", "Gene1", "Gene2"])
#pairs_df.to_csv("./data/pairs.csv", index=False)
pairs_df.to_csv("../pairs_1000.csv", index=False)

# %%
pairs_df
# Out:
#                                                  PMCID  \
# 0    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 1    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 2    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...
# 3    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
# 4    https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# ..                                                 ...
# 995  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 996  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2...
# 997  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 998  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...
# 999  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7...
#
#                                              Sentence1  \
# 0    Importantly, NAADP-induced currents were undet...
# 1     B , PCR screening of cell clones for deletion...
# 2    We used organotypic slice cultures of the huma...
# 3    Effect of Mfsd2a overexpression on learning an...
# 4    Our results indicate that the suspension trans...
# ..                                                 ...
# 995   (B)  Quantitative RT-PCR analysis for hepatic...
# 996  TG101209 is 25-fold more potent for Jak2 inhib...
# 997  Immunoprecipitation assay results for the phys...
# 998  From this experiment, we conclude that the Rad...
# 999  At first, a library of 12 compounds (reported ...
#
#                                              Sentence2   Gene1   Gene2
# 0    NAADP-stimulated Ca 2+  currents are absent in...   tpcn1   tpcn1
# 1     C , analysis of Myo9b protein expression by i...   myo9b   myo9b
# 2    Immunostaining with Nkx2.1 antibody confirmed ...   nkx21   nkx21
# 3     (A,B)  Representative immunofluorescence imag...  mfsd2a  mfsd2a
# 4    We specifically assessed the expression of key...    sox9  col1a1
# ..                                                 ...     ...     ...
# 995   (D)  Confocal microscopic images of immunocyt...    a1at   lamp2
# 996  We also tested the effects of two other Jak2 i...    jak2    jak2
# 997  Fbxw7 was detected by IB after IP pulldown wit...    cdk5   fbxw7
# 998  Figure 3 The Cdc45-Rad53 Interaction Is Requir...    sld3    sld3
# 999  However, compound  18  is an interesting excep...    faah    faah
#
# [1000 rows x 5 columns]
