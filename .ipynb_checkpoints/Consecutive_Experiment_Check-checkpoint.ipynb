# %%
#Open the file
import pandas as pd 
filepath = "./data/masked_sentences_bert.txt"
df = pd.read_table(filepath, header = None)
df.columns = ["Score","Year","PMCID","Gene","Experiment","Sentence","Masked"]
grouped = df.groupby('PMCID')
sent_ids = []

# Loop through each PMCID group
for _, group in grouped:
    sentences = group["Sentence"].tolist()
    sent_id = 1
    sent_ids.append(sent_id)
    
    # Check for consecutive sentences
    for i in range(1, len(sentences)):
        if sentences[i] != sentences[i-1]:
            sent_id += 1
        sent_ids.append(sent_id)

# Add as a new column
df["SentID"] = sent_ids

# %%
import random
import pandas as pd
random.seed(100)

pairs = []
while len(pairs) < 10:  #10 pairs for demonstration
    idx = random.randint(0, len(df) - 2)
    row1, row2 = df.iloc[idx], df.iloc[idx+1]
    
    # Check if rows have the same PMCID and different sentences
    if row1["PMCID"] == row2["PMCID"] and row1["Sentence"] != row2["Sentence"]:
        pairs.append((row1["PMCID"].split("-")[0], row1["Sentence"], row2["Sentence"], row1["Gene"], row2["Gene"]))

pairs_df = pd.DataFrame(pairs, columns=["PMCID", "Sentence1", "Sentence2", "Gene1", "Gene2"])
pairs_df.to_csv("./data/pairs.csv", index=False)

# %%
pairs_df[:5]
# Out:
#         PMCID                                          Sentence1  \
# 0  PMC5509424  Considering that the expression levels of seve...
# 1  PMC6389942  Fig. 3 Depletion of Cep57 or  cep57  mutations...
# 2  PMC6777370  Representative high-resolution immunofluoresce...
# 3  PMC7812875  As expected, the amount of pericentrin at PCM ...
# 4  PMC4220463  First, to investigate the physical interaction...
#
#                                            Sentence2   Gene1   Gene2
# 0  To overcome the G1 arrest that was induced upo...    nek7    nek7
# 1  MVA patients’ lymphoblastoid cell lines (LCLs)...   cep57  cep192
# 2  HeLa cells were transfected with siControl, si...  cep152    stil
# 3  Subsequently, to analyze the effect of CEP57 d...   cep57   cep57
# 4  Moreover, yeast two-hybrid and  in vitro  bind...    stil    plk4

# %%
#Evaluation results used in the main manuscript
import pandas as pd
df = pd.read_csv("./data/consecutive_test.csv")
df[:5]
# Out:
#         PMCID                                          Sentence1  \
# 0  PMC4516428  Importantly, NAADP-induced currents were undet...
# 1  PMC7949024   B , PCR screening of cell clones for deletion...
# 2  PMC4306459  We used organotypic slice cultures of the huma...
# 3  PMC7308492  Effect of Mfsd2a overexpression on learning an...
# 4  PMC6337215  Our results indicate that the suspension trans...
#
#                                            Sentence2   Gene1   Gene2  \
# 0  NAADP-stimulated Ca 2+  currents are absent in...   tpcn1   tpcn1
# 1   C , analysis of Myo9b protein expression by i...   myo9b   myo9b
# 2  Immunostaining with Nkx2.1 antibody confirmed ...   nkx21   nkx21
# 3   (A,B)  Representative immunofluorescence imag...  mfsd2a  mfsd2a
# 4  We specifically assessed the expression of key...    sox9  col1a1
#
#    Consecutive
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True

# %%
df_same_gene = df[df['Gene1'] == df['Gene2']]
print("Tuples including the same gene")
print(df_same_gene['Consecutive'].value_counts())
print("")

df_different_genes = df[df['Gene1'] != df['Gene2']]
print("Tuples including different genes")
print(df_different_genes['Consecutive'].value_counts())
# Out:
# Tuples including the same gene
# True     108
# False     59
# Name: Consecutive, dtype: int64
#
# Tuples including different genes
# True     122
# False     11
# Name: Consecutive, dtype: int64
