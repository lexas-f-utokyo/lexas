# %%
import pandas as pd 
filepath = "./data/masked_sentences_bert.txt"
df = pd.read_table(filepath, header = None)
df.columns = ["Score","Year","PMCID","Gene","Experiment","Sentence","Masked"]
df
# Out:
#         Score  Year       PMCID     Gene Experiment  \
# 0    0.956300  2021  PMC7836272    cep57  depletion
# 1    0.963299  2021  PMC7836272  cep57l1  depletion
# 2    0.616958  2021  PMC7836272    cep57     sirnas
# 3    0.537571  2021  PMC7836272  cep57l1     sirnas
# 4    0.587691  2021  PMC7836272     pcnt     sirnas
# ..        ...   ...         ...      ...        ...
# 819  0.783914  2016  PMC5007451   cep192  pull-down
# 820  0.738170  2016  PMC5007451   cep192     assays
# 821  0.928319  2016  PMC5007451   cep192   depleted
# 822  0.679720  2016  PMC5007451   cep192   depleted
# 823  0.954017  2016  PMC5007451   cep192    rescued
#
#                                               Sentence  \
# 0    We recently reported that the Cep57–PCNT inter...
# 1    We found that depletion of Cep57L1 did not aff...
# 2    We accordingly tested codepletion of two of th...
# 3    We accordingly tested codepletion of two of th...
# 4    We accordingly tested codepletion of two of th...
# ..                                                 ...
# 819  We demonstrated that the two proteins interact...
# 820  We demonstrated that the two proteins interact...
# 821  We found that the Cep192 mutant did not rescue...
# 822  We found that the Cep192 mutant did not rescue...
# 823  We found that the Cep192 mutant did not rescue...
#
#                                                 Masked
# 0     We recently reported that the Cep57–PCNT inte...
# 1     We found that [EXPE] of [GENE] did not affect...
# 2     We accordingly tested codepletion of two of t...
# 3     We accordingly tested codepletion of two of t...
# 4     We accordingly tested codepletion of two of t...
# ..                                                 ...
# 819   We demonstrated that the two proteins interac...
# 820   We demonstrated that the two proteins interac...
# 821   We found that the Cep192 mutant did not rescu...
# 822   We found that the Cep192 mutant did not rescu...
# 823   We found that the Cep192 mutant did not rescu...
#
# [824 rows x 7 columns]

# %%
grouped = df.groupby('PMCID')
sent_ids = []

# Loop through each PMCID group
for _, group in grouped:
    sentences = group["Sentence"].tolist()
    sent_id = 1
    sent_ids.append(sent_id)
    
    # Check for consecutive sentences
    for i in range(1, len(sentences)):
        if sentences[i] != sentences[i-1]:
            sent_id += 1
        sent_ids.append(sent_id)

# Add as a new column
df["SentID"] = sent_ids

# %%
import random
import pandas as pd
random.seed(100)

pairs = []
while len(pairs) < 5:
    idx = random.randint(0, len(df) - 2)
    row1, row2 = df.iloc[idx], df.iloc[idx+1]
    
    # Check if rows have the same PMCID and different sentences
    if row1["PMCID"] == row2["PMCID"] and row1["Sentence"] != row2["Sentence"]:
        pairs.append((row1["PMCID"], row1["Sentence"], row2["Sentence"], row1["Gene"], row2["Gene"]))

pairs_df = pd.DataFrame(pairs, columns=["PMCID", "Sentence1", "Sentence2", "Gene1", "Gene2"])
pairs_df.to_csv("./data/pairs.csv", index=False)
